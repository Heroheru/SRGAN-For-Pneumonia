# %%
pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: torch in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (2.6.0+cu118)
# Requirement already satisfied: torchvision in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (0.21.0+cu118)
# Requirement already satisfied: torchaudio in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (2.6.0+cu118)
# Requirement already satisfied: filelock in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\heaven\anaconda3\envs\srgan_env\lib\site-packages (from jinja2->torch) (2.1.5)

# %%
pip install -r requirements.txt
# Out:
# Processing c:\home\conda\feedstock_root\build_artifacts\asttokens_1733250440834\work (from -r requirements.txt (line 1))
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'C:\\home\\conda\\feedstock_root\\build_artifacts\\asttokens_1733250440834\\work'
